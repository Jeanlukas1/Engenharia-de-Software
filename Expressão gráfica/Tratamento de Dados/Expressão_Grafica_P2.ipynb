# %% [markdown]
# |          |                          |
# | :------: | ----------------------: |
# | ![image.png](attachment:image.png) | **Curso de Engenharia de Software - Campus Saquarema - RJ** |
# | Disciplina: **Expressão Gráfica** | Período **1º** |
# | Professor: **Diego Ramos Inácio** | Aluno: **Jean lukas de marins costa do nascimento** |
# ***

# %%
# Resposta da Questão 2
# insira aqui suas opções
'Escolha:'
'https://dados.gov.br/dados/conjuntos-dados/taxas-dos-titulos-ofertados-pelo-tesouro-direto1'
# salve esse arquivo = "ctrl+s"

# %%
import pandas as pd

df_tesouro_direto = pd.read_csv(
   r'C:\Users\UNIVASSOURAS\OneDrive - Universidade de Vassouras\EXPRESSÃO GRÁFICA\PrecoTaxaTesouroDireto.csv')

df_tesouro_direto = pd.read_csv(r"C:\Users\UNIVASSOURAS\OneDrive - Universidade de Vassouras\EXPRESSÃO GRÁFICA\PrecoTaxaTesouroDireto.csv", sep=';')
df_tesouro_direto
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df_tesouro_direto = pd.read_csv(
#       4    r'C:\Users\UNIVASSOURAS\OneDrive - Universidade de Vassouras\EXPRESSÃO GRÁFICA\PrecoTaxaTesouroDireto.csv')
#       6 df_tesouro_direto = pd.read_csv(r"C:\Users\UNIVASSOURAS\OneDrive - Universidade de Vassouras\EXPRESSÃO GRÁFICA\PrecoTaxaTesouroDireto.csv", sep=';')
#       7 df_tesouro_direto
#
# ...

# %%
#dados nulos:
df_tesouro_direto.isnull().sum()
# Out:
# Tipo Titulo          0
# Data Vencimento      0
# Data Base            0
# Taxa Compra Manha    0
# Taxa Venda Manha     0
# PU Compra Manha      0
# PU Venda Manha       0
# PU Base Manha        0
# dtype: int64

# %%
#tamanho do df_tesouro_direto:
df_tesouro_direto.shape
df_tesouro = pd.DataFrame(
    
    {
    
    "linhas":["144193"],
    "colunas":["8"]
    
    }
)
df_tesouro
# Out:
#    linhas colunas
# 0  144193       8

# %%
#salvando.
df_tesouro_direto.to_excel(r"C:\Users\UNIVASSOURAS\OneDrive - Universidade de Vassouras\EXPRESSÃO GRÁFICA\PrecoTaxaTesouroDireto.xlsx", index=True)
