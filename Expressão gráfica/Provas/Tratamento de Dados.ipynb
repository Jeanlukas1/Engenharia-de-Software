# %% [markdown]
# |          |                          |
# | :------: | ----------------------: |
# | Tratamento de Dados  | Market Maps - Funcionalidades
# | | **Curso de Engenharia de Software - Campus Saquarema - RJ** |
# | Disciplina: **Expressão Gráfica** | Período **1º** |
# | Professor: **Diego Ramos Inácio** | Alunos: **Jean lukas de marins costa do nascimento, Cristian Bryan, Evandro Oliveira** |
# ***

# %%
#importando a biblioteca Pandas
import pandas as pd

# %%
#Lendo o arquivo do Excel Para tratamento
df_Market_Maps = pd.read_excel(
    r'C:\Users\Pichau\OneDrive - Universidade de Vassouras\EXPRESSÃO GRÁFICA\UML\_MARKET MAPS_ FUNCIONALIDADES.xlsx'
)
df_Market_Maps
# Out:
#     Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  MARKET MAPS: FUNCIONALIDADES  \
# 0              0             0           0          Carimbo de data/hora
# 1              1             1           1    2024-06-14 20:35:09.029000
# 2              2             2           2    2024-06-14 20:48:45.455000
# 3              3             3           3    2024-06-14 22:04:52.532000
# 4              4             4           4    2024-06-14 22:47:02.453000
# 5              5             5           5    2024-06-14 23:01:44.463000
# 6              6             6           6    2024-06-14 23:04:27.106000
# 7              7             7           7    2024-06-14 23:20:37.033000
# 8              8             8           8    2024-06-14 23:22:04.948000
# 9              9             9           9    2024-06-14 23:59:09.495000
# 10            10            10          10    2024-06-15 00:12:33.815000
# 11            11            11          11    2024-06-15 04:33:47.984000
# ...

# %%
#Tamanho
df_Market_Maps.shape
# Out:
# (19, 26)

# %%
#Dados Nulos
df_Market_Maps.isnull().sum()
# Out:
# Unnamed: 0.2                      0
# Unnamed: 0.1                      0
# Unnamed: 0                        0
#  MARKET MAPS: FUNCIONALIDADES     0
# Unnamed: 1                        0
# Unnamed: 2                        0
# Unnamed: 3                        0
# Unnamed: 4                        2
# Unnamed: 5                        0
# Unnamed: 6                       16
# Unnamed: 7                       18
# Unnamed: 8                        3
# Unnamed: 9                       18
# Unnamed: 10                      18
# Unnamed: 11                      16
# Unnamed: 12                      18
# Unnamed: 13                      16
# Unnamed: 14                      15
# Unnamed: 15                      15
# Unnamed: 16                      16
# Unnamed: 17                      16
# Unnamed: 18                       6
# Unnamed: 19                       6
# Unnamed: 20                       3
# Unnamed: 21                      10
# Unnamed: 22                      18
# ...

# %%
df_Market_Maps.notna().sum()
# Out:
# Unnamed: 0.2                     19
# Unnamed: 0.1                     19
# Unnamed: 0                       19
#  MARKET MAPS: FUNCIONALIDADES    19
# Unnamed: 1                       19
# Unnamed: 2                       19
# Unnamed: 3                       19
# Unnamed: 4                       17
# Unnamed: 5                       19
# Unnamed: 6                        3
# Unnamed: 7                        1
# Unnamed: 8                       16
# Unnamed: 9                        1
# Unnamed: 10                       1
# Unnamed: 11                       3
# Unnamed: 12                       1
# Unnamed: 13                       3
# Unnamed: 14                       4
# Unnamed: 15                       4
# Unnamed: 16                       3
# Unnamed: 17                       3
# Unnamed: 18                      13
# Unnamed: 19                      13
# Unnamed: 20                      16
# Unnamed: 21                       9
# Unnamed: 22                       1
# ...

# %%
#salvando dados para analise no Power BI
df_Market_Maps.to_excel(r"C:\Users\Pichau\OneDrive - Universidade de Vassouras\EXPRESSÃO GRÁFICA\UML\_MARKET MAPS_ FUNCIONALIDADES.xlsx", index=True)
