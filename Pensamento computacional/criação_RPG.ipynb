# %%
def escreva(msg):
    tam = len(msg) + 4
    print('~' * tam) 
    print(f'  {msg}')
    print('~' * tam)

import random
import time

import pygame
import time

pygame.init
pygame.mixer.music.load('a horror-sinister-power-rising-epic-dark- soundtracknocopyrightmusic98837.mp3')
pygame.mixer.music.play()

while pygame.mixer.music.get_busy():
    pygame.time.Clock().tick(10)

print(''' 
+--------------------------------------------------------------------------------------+
| _____ ___ _     _   _  ___  ____           ____   ___          ____ _____ _     ___  |
||  ___|_ _| |   | | | |/ _ \/ ___|         |  _ \ / _ \        / ___| ____| |   / _ \ |
|| |_   | || |   | |_| | | | \___ \         | | | | | | |      | |  _|  _| | |  | | | ||
||  _|  | || |___|  _  | |_| |___) |        | |_| | |_| |      | |_| | |___| |__| |_| ||
||_|___|___|_____|_|_|_|\___/|____/   __  __|____/ \___/_       \____|_____|_____\___/ |
|| ____|        |  _ \ / _ \         |  \/  |  / \  |  _ \                             |
||  _|          | | | | | | |        | |\/| | / _ \ | |_) |                            |
|| |___         | |_| | |_| |        | |  | |/ ___ \|  _ <                             |
||_____|        |____/ \___/         |_|  |_/_/   \_\_| \_\                            |
+--------------------------------------------------------------------------------------+
''')
texto = ''' 

~-~~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~~-~-~-~-~-~~-~~-~-~-~-~-~-~-~-~-~-~-~-
Nesse RPG você sera o personagem Ragnar o Destemido, um campones que vive em Kattegatt um Reino Nórdico,
controlado por grandes guerreiros Vikings. Ragnar tem uma esposa chamada astrid e 2 filhos, Harold e Magnus
é um homem robusto e imponente, com grandes músculos definidos por anos de treinamento e batalhas. 
Ele tem cabelo longo e uma barba grande que o deixa bem intimidador. Seus olhos são de um azul marcante, lembrando 
o gelo das terras do Norte aonde ele vive. 
E é aqui que nossa Hisória começa. 
~-~~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~~-~-~-~-~-~~-~~-~-~-~-~-~-~-~-~-~-~-~-
'''

for letra in texto:
  print(letra, end='', flush=True)
  time.sleep(0.1)
      
escreva('''
Você está no campo com a sua esposa Astrid fazendo a colheita, e seus amigos guerreiros te chamam para ir ao bar, dizendo que precisam falar com você algo importante. ''')
print('''3
      
      [1] ir ao bar
      [2] ficar com astrid
      
      ''')
escolha = input('Sua escolha')
if escolha == '1':
    print('Você foi ao bar......')
    print('''
          
          
    ) )        /\
   =====      /  \
  _|___|_____/ __ \____________
 |::::::::::/ |BAR|\:::::::::::|
 |:::::::::/  ====  \::::::::::|
 |::::::::/__________\-:::::::::|
 |_________|  ____  |__________|
  | ______ | / || \ | _______ |
  ||  |   || ====== ||   |   ||
  ||--+---|| |    | ||---+---||
  ||__|___|| |   o| ||___|___||
  |========| |____| |=========|
 (^^-^^^^^-|________|-^^^--^^^)
 (,, , ,, ,/________\,,,, ,, ,)
','',,,,' /__________\,,,',',;;
            
            
            ''')
    escreva('''Chegando lá um de seus amigos Seagurd conta que o lord Garric (o lord Garric é o lord de kattegat, um líder incompetente e sem visão) \nimpediu que os gurreiros fossem em uma expedição que com certeza traria bastante recursos para Kattegat.
    você olha para todos os geurreiros que estavam alí e diz: "EU CONVOCO TODOS OS GUERREIROS DE KATTEGAT QUE VENHAM COMIGO AMANHÂ PARA O MAR, ACHAR TERRA TENHO CERTEZA QUE AONDE ENCORARMOS O NOSSO BARCO SEREMOS VITORIOSOS!!!!!!!"
    todos os guerreiro te apoiaram e gritaram com bravura: "AHHHHHHHHHH VAMOSSSS!!!!!!"''')
    print()
    print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
    escreva('''O dia amanhaceu, Astrid ficou sabendo do plano e contou para os seus filhos que você estava partindo, você se despediu e foi. \nOs guerreiros ja estavam te esperando para pegar os barcos, 'está na hora de pôr o plano em prática' eles disseram!!. \nVocê e os guerreiro esperaram a hora certa em que os guardas saíram dos seus postos e pegaram os barcos. ''')
    print()
    print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
    escreva('você e mais três barcos foram em direção ao norte em busca de terra...')
    print()
    escreva('Depois de 3 dias vocês acharam um lugar.')
    print('''                              |>>>                              
                                  |                                 
                    |>>>      _  _|_  _         |>>>                
                    |        |;| |;| |;|        |                   
                _  _|_  _    \\.    .  /    _  _|_  _               
               |;|_|;|_|;|    \\:. ,  /    |;|_|;|_|;|              
               \\..      /    ||;   . |    \\.    .  /              
                \\.  ,  /     ||:  .  |     \\:  .  /               
                 ||:   |_   _ ||_ . _ | _   _||:   |                
                 ||:  .|||_|;|_|;|_|;|_|;|_|;||:.  |                
                 ||:   ||.    .     .      . ||:  .|                
                 ||: . || .     . .   .  ,   ||:   |       \,/      
                 ||:   ||:  ,  _______   .   ||: , |            /`\ 
                 ||:   || .   /+++++++\    . ||:   |                
                 ||:   ||.    |+++++++| .    ||: . |                
              __ ||: . ||: ,  |+++++++|.  . _||_   |                
     ____--`~    '--~~__|.    |+++++__|----~    ~`---,              
-~--~                   ~---__|,--~'                  ~~----_____-~''')
    escreva('Um castelo que a princípio tinha acabado de ser invadido por outros gurreiros, vocês entraram para vasculhar e ver se ainda tinha espólios perdidos, quando de repente surge um soldado e te ataca!!!')
    print('''
      [1] rolar os dados
          ''')
    escolha_334 = input('Sua escolha: ')
    if escolha_334 == '1':
          print('você jogou os dados!!')
          dados = random.randint(1,10)
          print(dados)
          if dados >= 7:
                print('você puxou a espada a tempo e consegui se defender!!')
                print()
                print('''
              
      [O inimigo é de nível 3]
              
              ''')
                print()
                print('Ele te ataca novamente!!!')
                print()
                print('''
      [1] rolar os dados
          ''')
                escolha_541 = input('Sua escolha: ')
                if escolha_541 == '1':
                      print('Você jogou os dados')
                      print(dados)
                      print()
                      if dados >= 7:
                            print('O inimigo vem pra cima e você com um só golpe o finaliza!!')
                            print()
                            escreva('Você e seus companheiros comemoram e terminam de saquear aquele castelo.')
                            print()
                            escreva('Depois de 2 dias de descanso vocês voltaram para Kattegatt')
                            print()
                            print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                            escreva('Durante a viagem de volta, você e seus companheiros vikings discutiram sobre como o lord Garric estava exercendo o seu governo em kattegatt.')
                            escreva('Neste momento, você pensou e se eu desafiar o lord Garric para uma batalha......')
                            escreva('Chegando em kattegatt, você reencontra a sua família e vai pra casa')
                            print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
                            escreva('Mais uma vez o sol sai da sua toca...... e aquele pensamento não sai da sua cabeça.')
                            escreva('você fala com astrid, pedindo um conselho, ela diz: "Eu acho que isso mudaria a nossa vida e a vida dos nossos filhos, pense, se você ganhar dele kattegatt pode virar um novo reino, não era isso que você sempre quis."')
                            print('''
          [1] sim   
          [2] Não, estou com medo   
                  ''')
                            escolha_594 = input('Você diz ')
                            if escolha_594 == '1':
                                  print('sim, você tem razão, vou desafia-lo a uma batalha')
                                  escreva('Imediatamente você se reuniu com os seus companheiros vinkings e foi até o lord garric.')
                                  escreva('Chegando lá lord Garric saiu para ver oque estava acontecendo.')
                                  escreva('você em alto e bom som grita: "Eu vim te desafiar Garric para uma batalha até a morte pelo trono de kattegatt."')
                                  escreva('Lord Garric diz: "haahaahaaahaa!!! e vira as costas."')
                                  escreva('Você diz: "está com medo, hahahaha!!!"')
                                  escreva('A população começa a gritar: "COVARDEEEE!!, NÃO ACREDITO QUE ESSE É O HOMEM QUE SE DIZ SER O NOSSO LORD!!!!"')
                                  escreva('Devido a pressão da população de kattegatt, o lord garric vai para a luta!!')
                                  escreva('Uma roda é formada (o lord Garric parece estar nervoso, mas não o subestime.) ')
                                  escreva('você diz: será travada uma batalha aqui hoje, até a morte, porque nós somos vikings e quando não estamos satisfeitos nós matamos Hahahahahah!')
                                  print('A batalha começa...')
                                  print('''
                    
                    
          [O inimigo é de nivel 10]        
                    
                    
                    ''')
                                  print('lord Garric ataca com sua espada, que é bem melhor que a sua...')
                                  print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                  escolha_723 = input('Sua escolha: ')
                                  print('Você jogou os dados!!')
                                  print(dados)
                                  print()
                                  if dados >= 7:
                                        print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                                        print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                        escolha_10134 = input('Sua escolha: ')
                                        if escolha_10134 == '1':
                                          print('Você jogou os dados!!!')
                                          print(dados)
                                          if dados >= 7:
                                              print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                              escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                              texto = 'CONTINUA.......'
                                          else:
                                            print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                            escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                            texto = 'CONTINUA.......'
                                  else:
                                    print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                                    print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                    escolha_1034 = input('Sua escolha: ')
                                    if escolha_1034 == '1':
                                      print('Você jogou os dados!!!')
                                      print(dados)
                                      if dados >= 7:
                                        print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                        escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                        texto = 'CONTINUA.......'
                                      else:
                                        print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                        escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                        texto = 'CONTINUA.......'
                                                  
                                              
                                              
                            else: 
                                  print('Bom, se você é um medroso não deveria ser um viking...')
                                  texto = 'CONTINUAÇÂO PARA MEDROSOS EM BREVE!!!'              
                      else:
                        print('O inimigo vem pra cima e você com um só golpe o finaliza!!')
                        print()
                        escreva('Você e seus companheiros comemoram e terminam de saquear aquele castelo.')
                        print()
                        escreva('Depois de 2 dias de descanso vocês voltaram para Kattegatt')
                        print()
                        print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                        escreva('Durante a viagem de volta, você e seus companheiros vikings discutiram sobre como o lord Garric estava exercendo o seu governo em kattegatt.')
                        escreva('Neste momento, você pensou e se eu desafiar o lord Garric para uma batalha......')
                        escreva('Chegando em kattegatt, você reencontra a sua família e vai pra casa')
                        print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
                        escreva('Mais uma vez o sol sai da sua toca...... e aquele pensamento não sai da sua cabeça.')
                        escreva('você fala com astrid, pedindo um conselho, ela diz: "Eu acho que isso mudaria a nossa vida e a vida dos nossos filhos, pense, se você ganhar dele kattegatt pode virar um novo reino, não era isso que você sempre quis."')
                        print('''
          [1] sim   
          [2] Não, estou com medo   
                  ''')
                        escolha_582 = input('Você diz ')
                        if escolha_582 == '1':
                          print('sim, você tem razão, vou desafia-lo a uma batalha')
                          escreva('Imediatamente você se reuniu com os seus companheiros vinkings e foi até o lord garric.')
                          escreva('Chegando lá lord Garric saiu para ver oque estava acontecendo.')
                          escreva('você em alto e bom som grita: "Eu vim te desafiar Garric para uma batalha até a morte pelo trono de kattegatt."')
                          escreva('Lord Garric diz: "haahaahaaahaa!!! e vira as costas."')
                          escreva('Você diz: "está com medo, hahahaha!!!"')
                          escreva('A população começa a gritar: "COVARDEEEE!!, NÃO ACREDITO QUE ESSE É O HOMEM QUE SE DIZ SER O NOSSO LORD!!!!"')
                          escreva('Devido a pressão da população de kattegatt, o lord garric vai para a luta!!')
                          escreva('Uma roda é formada (o lord Garric parece estar nervoso, mas não o subestime.) ')
                          escreva('você diz: será travada uma batalha aqui hoje, até a morte, porque nós somos vikings e quando não estamos satisfeitos nós matamos Hahahahahah!')
                          print('A batalha começa...')
                          print('''
                    
                    
          [O inimigo é de nivel 10]        
                    
                    
                    ''')
                          print('lord Garric ataca com sua espada, que é bem melhor que a sua...')
                          print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                          escolha_739 = input('Sua escolha: ')
                          print('Você jogou os dados!!')
                          print(dados)
                          print()
                          if dados >= 7:
                            print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                            print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                            escolha_1100 = input('Sua escolha: ')
                            if escolha_1100 == '1':
                              print('Você jogou os dados!!!')
                              print(dados)
                              if dados >= 7:
                                print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                texto = 'CONTINUA.......'
                              else:
                                print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                texto = 'CONTINUA.......'
                          else:
                            print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                            escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                            texto = 'CONTINUA.......'
                        
                        else: 
                            print('Bom, se você é um medroso não deveria ser um viking...')
                            texto = 'CONTINUAÇÂO PARA MEDROSOS EM BREVE!!!'    
                                              
        
                
          else:
            print('você não consegui puxar a espada porém consegui se desviar a tempo, mas mesmo assim ainda sofreu um corte no braço.')
            print('''
              
      [O inimigo é de nível 3]
              
              ''')
            print('Você grita para todos os seus companheiros, ESSE É MEUU!!!')
            print('''
      [1] rolar os dados
          ''')
            escolha_126 = input('Sua escolha: ')
            if escolha_126 == '1':
              print('Você jogou os dados!!!')
              print(dados)
              if dados >= 7:
                print('Você empunha a sua espada e com um só golpe você mata o inimigo!!')
                escreva('todos gritam e se alegram com a vitória')
                escreva('Depois de 2 dias de descanso vocês voltaram para Kattegatt')
                print()
                print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                escreva('Durante a viagem de volta, você e seus companheiros vikings discutiram sobre como o lord Garric estava exercendo o seu governo em kattegatt.')
                escreva('Neste momento, você pensou e se eu desafiar o lord Garric para uma batalha......')
                escreva('Chegando em kattegatt, você reencontra a sua família e vai pra casa')
                print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
                escreva('Mais uma vez o sol sai da sua toca...... e aquele pensamento não sai da sua cabeça.')
                escreva('você fala com astrid, pedindo um conselho, ela diz: "Eu acho que isso mudaria a nossa vida e a vida dos nossos filhos, pense, se você ganhar dele kattegatt pode virar um novo reino, não era isso que você sempre quis."')
                print('''
          [1] sim   
          [2] Não, estou com medo   
                  ''')
                escolha_918 = input('Você diz ')
                if escolha_918 == '1':
                  print('sim, você tem razão, vou desafia-lo a uma batalha')
                  escreva('Imediatamente você se reuniu com os seus companheiros vinkings e foi até o lord garric.')
                  escreva('Chegando lá lord Garric saiu para ver oque estava acontecendo.')
                  escreva('você em alto e bom som grita: "Eu vim te desafiar Garric para uma batalha até a morte pelo trono de kattegatt."')
                  escreva('Lord Garric diz: "haahaahaaahaa!!! e vira as costas."')
                  escreva('Você diz: "está com medo, hahahaha!!!"')
                  escreva('A população começa a gritar: "COVARDEEEE!!, NÃO ACREDITO QUE ESSE É O HOMEM QUE SE DIZ SER O NOSSO LORD!!!!"')
                  escreva('Devido a pressão da população de kattegatt, o lord garric vai para a luta!!')
                  escreva('Uma roda é formada (o lord Garric parece estar nervoso, mas não o subestime.) ')
                  escreva('você diz: será travada uma batalha aqui hoje, até a morte, porque nós somos vikings e quando não estamos satisfeitos nós matamos Hahahahahah!')
                  print('A batalha começa...')
                  print('''
                    
                    
          [O inimigo é de nivel 10]        
                    
                    
                    ''')
                  print('lord Garric ataca com sua espada, que é bem melhor que a sua...')
                  print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                  escolha_869 = input('Sua escolha: ')
                  if escolha_869 == '1':
                    print('Você jogou os dados!!!!')
                    print(dados)
                    print()
                    if dados >= 7:
                      print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                      print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                      escolha_1150 = input('Sua escolha: ')
                      if escolha_1150 == '1':
                        print('Você jogou os dados!!')
                        print(dados)
                        if dados >= 7:
                          print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                          escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                          texto = 'CONTINUA.......'
                        else:
                          print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                          escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                          texto = 'CONTINUA.......'
                    
                    else:
                        print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                        escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                        texto = 'CONTINUA.......'
                          
                else:
                  print('Bom, se você é um medroso não deveria ser um viking...')
                  texto = 'CONTINUAÇÂO PARA MEDROSOS EM BREVE!!!'
                                 
              else:
                print('Você empunha a espada e vai pra cima do inimigo, com muita dificuldade você consegue derrota-lo!')
                escreva('Seagurd olha pra você e diz: "hahaha está ficando lento amigo!!! "')
                escreva('Você e seus companheiros comemoram e terminam de saquear aquele castelo.')
                print()
                escreva('Depois de 2 dias de descanso vocês voltaram para Kattegatt')
                print()
                print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                escreva('Durante a viagem de volta, você e seus companheiros vikings discutiram sobre como o lord Garric estava exercendo o seu governo em kattegatt.')
                escreva('Neste momento, você pensou e se eu desafiar o lord Garric para uma batalha......')
                escreva('Chegando em kattegatt, você reencontra a sua família e vai pra casa')
                print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
                escreva('Mais uma vez o sol sai da sua toca...... e aquele pensamento não sai da sua cabeça.')
                escreva('você fala com astrid, pedindo um conselho, ela diz: "Eu acho que isso mudaria a nossa vida e a vida dos nossos filhos, pense, se você ganhar dele kattegatt pode virar um novo reino, não era isso que você sempre quis."')
                print('''
          [1] sim   
          [2] Não, estou com medo   
                  ''')
                escolha_520 = input('Você diz: ')
                if escolha_520 == '1':
                  print('sim, você tem razão, vou desafia-lo a uma batalha')
                  escreva('Imediatamente você se reuniu com os seus companheiros vinkings e foi até o lord garric.')
                  escreva('Chegando lá lord Garric saiu para ver oque estava acontecendo.')
                  escreva('você em alto e bom som grita: "Eu vim te desafiar Garric para uma batalha até a morte pelo trono de kattegatt."')
                  escreva('Lord Garric diz: "haahaahaaahaa!!! e vira as costas."')
                  escreva('Você diz: "está com medo, hahahaha!!!"')
                  escreva('A população começa a gritar: "COVARDEEEE!!, NÃO ACREDITO QUE ESSE É O HOMEM QUE SE DIZ SER O NOSSO LORD!!!!"')
                  escreva('Devido a pressão da população de kattegatt, o lord garric vai para a luta!!')
                  escreva('Uma roda é formada (o lord Garric parece estar nervoso, mas não o subestime.) ')
                  escreva('você diz: será travada uma batalha aqui hoje, até a morte, porque nós somos vikings e quando não estamos satisfeitos nós matamos Hahahahahah!')
                  print('A batalha começa...')
                  print('''
                    
                    
          [O inimigo é de nivel 10]        
                    
                    
                    ''')
                  print('lord Garric ataca com sua espada, que é bem melhor que a sua...')
                  print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                  escolha_2211 = input('Sua escolha: ')
                  if escolha_2211 == '1':
                    print(dados)
                    print()
                    if dados >= 7:
                      print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                      print('''
          [1] Role os dados!!     
                  
                  ''')  
                      escolha_2323 = input('Sua escolha: ')
                      if escolha_2323 == '1':
                        print(dados)
                        if dados >= 7:
                          print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                          escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                          texto = 'CONTINUA.......'
                        else:
                          print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                          escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                          texto = 'CONTINUA.......'
                    else:
                       print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                       print('''
          [1] Role os dados!!     
                  
                  ''')
                       escolha_23343 = input('Sua escolha: ')
                       if escolha_23343 == '1':
                         print(dados)
                         if dados >= 7:
                           print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                           escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                           texto = 'CONTINUA.......'
                         else:
                            print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                            escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                            texto = 'CONTINUA.......'  
                
                else:
                  print('Bom, se você é um medroso não deveria ser um viking...')
                  texto = 'CONTINUAÇÂO PARA MEDROSOS EM BREVE!!!'
                                                
                 
                                   
    
elif escolha == '2':
    print('mas você ficou no campo com a Astrid, ajudando a terminar o dia de colheita! \nA noite vem, você esta deitado na cama é possível ver as estrelas no céu')
    print('''
      [1] ir dormir
      [2] continuar olhando as estrelas
          ''')
    escolha_2 = input('Sua escolha: ')
    if escolha_2 == '1':
          print('Você dormiu!! ')
          print()
          escreva('Um novo dia começa o sol está brilhando!!!! \nVocê passa pela cidade de manhã e encontra o seu amigo seagurd, e o chama para ir conversar com o lord Garric (o lord Garric é o lord de kattegat, um líder incompetente e sem visão). \nNo caminho você passa na frente da cabana de um vidente....')
          print('''
      [1] ir conversar com o lord Garric
      [2] entrar na cabana do vidente
                ''')
          escolha_3 = input("Sua escolha: ")
          if escolha_3 == '1':
                print('Você chegou na casa do lord Garric, ele te convida para sentar-se')
                print('''
      [1] Sentar
      [2] ficar em pé
                      ''')
                escolha_4 = input('Sua escolha: ')
                if escolha_4 == '1':
                      print('Você se sentou olhando para o lord Garric, ele fica um pouco desconfortável e logo pergunta: "oque quer meu caro Ragnar?" \nVocê diz em um tom alto: "Quando vamos para a expedição?" \nele diz com um voz sarcástica: "nunca, e eu ja te falei o porque, agora vá" \nVocê ri dizendo: "Você vai se arrepender disso, você sabe que lá fora existem reinos, povos e tesouros escondidos esperando alguém achar, porém a sua visão limitada te impede de exergar tal riqueza " \nDepois disso você voltou pra casa e armou um plano com os guerreiros de kattegat, com a intenção de pegar os barcos escondido e viajar')
                      print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                      escreva('você e mais três barcos foram em direção ao norte em busca de terra...')
                      print()
                      escreva('Depois de 3 dias vocês acharam um lugar.')
                      print(''' 
                                  |>>>                              
                                  |                                 
                    |>>>      _  _|_  _         |>>>                
                    |        |;| |;| |;|        |                   
                _  _|_  _    \\.    .  /    _  _|_  _               
               |;|_|;|_|;|    \\:. ,  /    |;|_|;|_|;|              
               \\..      /    ||;   . |    \\.    .  /              
                \\.  ,  /     ||:  .  |     \\:  .  /               
                 ||:   |_   _ ||_ . _ | _   _||:   |                
                 ||:  .|||_|;|_|;|_|;|_|;|_|;||:.  |                
                 ||:   ||.    .     .      . ||:  .|                
                 ||: . || .     . .   .  ,   ||:   |       \,/      
                 ||:   ||:  ,  _______   .   ||: , |            /`\ 
                 ||:   || .   /+++++++\    . ||:   |                
                 ||:   ||.    |+++++++| .    ||: . |                
              __ ||: . ||: ,  |+++++++|.  . _||_   |                
     ____--`~    '--~~__|.    |+++++__|----~    ~`---,              
-~--~                   ~---__|,--~'                  ~~----_____-~''')
                      escreva('Um castelo que a princípio tinha acabado de ser invadido por outros gurreiros, vocês entraram para vasculhar e ver se ainda tinha espólios perdidos, quando de repente surge um soldado e te ataca!!!')
                      print('''
      [1] rolar os dados
          ''')
                      escolha_324 = input('Sua escolha: ')
                      if escolha_324 == '1':
                        print('você jogou os dados!!')
                        dados = random.randint(1,10)
                        print(dados)
                        if dados >= 7:
                          print('você puxou a espada a tempo e consegui se defender!!')
                          print()
                          print('''
              
      [O inimigo é de nível 3]
              
              ''')
                          print()
                          print('Ele te ataca novamente!!!')
                          print()
                          print('''
      [1] rolar os dados
          ''')
                          escolha_2251 = input('Sua escolha: ')
                          if escolha_2251 == '1':
                            print('Você jogou os dados')
                            print(dados)
                            print()
                            if dados >= 7:
                              print('O inimigo vem pra cima e você com um só golpe o finaliza!!')
                              print()
                              escreva('Você e seus companheiros comemoram e terminam de saquear aquele castelo.')
                              print()
                              escreva('Depois de 2 dias de descanso vocês voltaram para Kattegatt')
                              print()
                              print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                              escreva('Durante a viagem de volta, você e seus companheiros vikings discutiram sobre como o lord Garric estava exercendo o seu governo em kattegatt.')
                              escreva('Neste momento, você pensou e se eu desafiar o lord Garric para uma batalha......')
                              escreva('Chegando em kattegatt, você reencontra a sua família e vai pra casa')
                              print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
                              escreva('Mais uma vez o sol sai da sua toca...... e aquele pensamento não sai da sua cabeça.')
                              escreva('você fala com astrid, pedindo um conselho, ela diz: "Eu acho que isso mudaria a nossa vida e a vida dos nossos filhos, pense, se você ganhar dele kattegatt pode virar um novo reino, não era isso que você sempre quis."')
                              print('''
          [1] sim   
          [2] Não, estou com medo   
                  ''')
                              escolha_529 = input('Você diz ')
                              if escolha_529 == '1':
                                  print('sim, você tem razão, vou desafia-lo a uma batalha')
                                  escreva('Imediatamente você se reuniu com os seus companheiros vinkings e foi até o lord garric.')
                                  escreva('Chegando lá lord Garric saiu para ver oque estava acontecendo.')
                                  escreva('você em alto e bom som grita: "Eu vim te desafiar Garric para uma batalha até a morte pelo trono de kattegatt."')
                                  escreva('Lord Garric diz: "haahaahaaahaa!!! e vira as costas."')
                                  escreva('Você diz: "está com medo, hahahaha!!!"')
                                  escreva('A população começa a gritar: "COVARDEEEE!!, NÃO ACREDITO QUE ESSE É O HOMEM QUE SE DIZ SER O NOSSO LORD!!!!"')
                                  escreva('Devido a pressão da população de kattegatt, o lord garric vai para a luta!!')
                                  escreva('Uma roda é formada (o lord Garric parece estar nervoso, mas não o subestime.) ')
                                  escreva('você diz: será travada uma batalha aqui hoje, até a morte, porque nós somos vikings e quando não estamos satisfeitos nós matamos Hahahahahah!')
                                  print('A batalha começa...')
                                  print('''
                    
                    
          [O inimigo é de nivel 10]        
                    
                    
                    ''')
                                  print('lord Garric ataca com sua espada, que é bem melhor que a sua...')
                                  print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                  escolha_7222 = input('Sua escolha: ')
                                  print('Você jogou os dados!!')
                                  print(dados)
                                  print()
                                  if dados >= 7:
                                        print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                                        print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                        escolha_12102 = input('Sua escolha: ')
                                        if escolha_12102 == '1':
                                          print('Você jogou os dados!!!')
                                          print(dados)
                                          if dados >= 7:
                                              print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                              escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                              texto = 'CONTINUA.......'
                                          else:
                                            print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                            escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                            texto = 'CONTINUA.......'
                                              
                                  else:
                                     print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                                     print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                     escolha_1202 = input('Sua escolha: ')
                                     if escolha_1202 == '1':
                                       print('Você jogou os dados!!!')
                                       print(dados)
                                       if dados >= 7:
                                         print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                         escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                         texto = 'CONTINUA.......'
                                       else:
                                         print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                         escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                         texto = 'CONTINUA.......'
                                                
                            else:
                              print('Bom, se você é um medroso não deveria ser um viking...')
                              texto = 'CONTINUAÇÂO PARA MEDROSOS EM BREVE!!!'
                                    
                                              
                        
                        else:
                          print('Você empunha a espada e vai pra cima do inimigo, com muita dificuldade você consegue derrota-lo!')
                          escreva('Seagurd olha pra você e diz: "hahaha está ficando lento amigo!!! "')
                          escreva('Você e seus companheiros comemoram e terminam de saquear aquele castelo.')
                          print()
                          escreva('Depois de 2 dias de descanso vocês voltaram para Kattegatt')
                          print()
                          print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                          escreva('Durante a viagem de volta, você e seus companheiros vikings discutiram sobre como o lord Garric estava exercendo o seu governo em kattegatt.')
                          escreva('Neste momento, você pensou e se eu desafiar o lord Garric para uma batalha......')
                          escreva('Chegando em kattegatt, você reencontra a sua família e vai pra casa')
                          print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
                          escreva('Mais uma vez o sol sai da sua toca...... e aquele pensamento não sai da sua cabeça.')
                          escreva('você fala com astrid, pedindo um conselho, ela diz: "Eu acho que isso mudaria a nossa vida e a vida dos nossos filhos, pense, se você ganhar dele kattegatt pode virar um novo reino, não era isso que você sempre quis."')
                          print('''
          [1] sim   
          [2] Não, estou com medo   
                  ''')
                          escolha_50 = input('Você diz: ')
                          if escolha_50 == '1':
                            print('sim, você tem razão, vou desafia-lo a uma batalha')
                            escreva('Imediatamente você se reuniu com os seus companheiros vinkings e foi até o lord garric.')
                            escreva('Chegando lá lord Garric saiu para ver oque estava acontecendo.')
                            escreva('você em alto e bom som grita: "Eu vim te desafiar Garric para uma batalha até a morte pelo trono de kattegatt."')
                            escreva('Lord Garric diz: "haahaahaaahaa!!! e vira as costas."')
                            escreva('Você diz: "está com medo, hahahaha!!!"')
                            escreva('A população começa a gritar: "COVARDEEEE!!, NÃO ACREDITO QUE ESSE É O HOMEM QUE SE DIZ SER O NOSSO LORD!!!!"')
                            escreva('Devido a pressão da população de kattegatt, o lord garric vai para a luta!!')
                            escreva('Uma roda é formada (o lord Garric parece estar nervoso, mas não o subestime.) ')
                            escreva('você diz: será travada uma batalha aqui hoje, até a morte, porque nós somos vikings e quando não estamos satisfeitos nós matamos Hahahahahah!')
                            print('A batalha começa...')
                            print('''
                    
                    
          [O inimigo é de nivel 10]        
                    
                    
                    ''')
                            print('lord Garric ataca com sua espada, que é bem melhor que a sua...')
                            print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                            escolha_211 = input('Sua escolha: ')
                            if escolha_211 == '1':
                              print(dados)
                              print()
                              if dados >= 7:
                                print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                                print('''
          [1] Role os dados!!     
                  
                  ''')  
                                escolha_233 = input('Sua escolha: ')
                                if escolha_233 == '1':
                                  print(dados)
                                  if dados >= 7:
                                    print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                    escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                    texto = 'CONTINUA.......'
                                  else:
                                    print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                    escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                    texto = 'CONTINUA.......'
                              else:
                                print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                                print('''
          [1] Role os dados!!     
                  
                  ''')
                                escolha_2333 = input('Sua escolha: ')
                                if escolha_2333 == '1':
                                  print(dados)
                                  if dados >= 7:
                                    print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                    escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                    texto = 'CONTINUA.......'
                                  else:
                                    print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                    escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                    texto = 'CONTINUA.......'  
                                              
                                                
                                              
                                              
                                              
                          else: 
                              print('Bom, se você é um medroso não deveria ser um viking...')
                              texto = 'CONTINUAÇÂO PARA MEDROSOS EM BREVE!!!'              
    
                elif escolha_4 == '2':
                  print('Você fica em pé demonstrando superioridade ele fica um pouco desconfortável e logo pergunta: "oque quer meu caro Ragnar?" \nVocê diz em um tom alto: "Quando vamos para a expedição?" \nele diz com um voz sarcástica: "nunca, e eu ja te falei o porque, agora vá" \nVocê ri dizendo: "Você vai se arrepender disso, você sabe que lá fora existem reinos, povos e tesouros escondidos esperando alguém achar, porém a sua visão limitada te impede de exergar tal riqueza " \nDepois disso você voltou pra casa e armou um plano com os guerreiros de kattegat, com a intenção de pegar os barcos escondido e viajar')
                  print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                  escreva('você e mais três barcos foram em direção ao norte em busca de terra...')
                  print()
                  escreva('Depois de 3 dias vocês acharam um lugar.')
                  print('''                              |>>>                              
                                  |                                 
                    |>>>      _  _|_  _         |>>>                
                    |        |;| |;| |;|        |                   
                _  _|_  _    \\.    .  /    _  _|_  _               
               |;|_|;|_|;|    \\:. ,  /    |;|_|;|_|;|              
               \\..      /    ||;   . |    \\.    .  /              
                \\.  ,  /     ||:  .  |     \\:  .  /               
                 ||:   |_   _ ||_ . _ | _   _||:   |                
                 ||:  .|||_|;|_|;|_|;|_|;|_|;||:.  |                
                 ||:   ||.    .     .      . ||:  .|                
                 ||: . || .     . .   .  ,   ||:   |       \,/      
                 ||:   ||:  ,  _______   .   ||: , |            /`\ 
                 ||:   || .   /+++++++\    . ||:   |                
                 ||:   ||.    |+++++++| .    ||: . |                
              __ ||: . ||: ,  |+++++++|.  . _||_   |                
     ____--`~    '--~~__|.    |+++++__|----~    ~`---,              
-~--~                   ~---__|,--~'                  ~~----_____-~''')
                  escreva('Um castelo que a princípio tinha acabado de ser invadido por outros gurreiros, vocês entraram para vasculhar e ver se ainda tinha espólios perdidos, quando de repente surge um soldado e te ataca!!!')
                  print('''
      [1] rolar os dados
          ''')
                  escolha_34 = input('Sua escolha: ')
                  if escolha_34 == '1':
                    print('você jogou os dados!!')
                    dados = random.randint(1,10)
                    print(dados)
                    if dados >= 7:
                      print('você puxou a espada a tempo e consegui se defender!!')
                      print()
                      print('''
              
      [O inimigo é de nível 3]
              
              ''')
                      print()
                      print('Ele te ataca novamente!!!')
                      print()
                      print('''
      [1] rolar os dados
          ''')
                      escolha_51 = input('Sua escolha: ')
                      if escolha_51 == '1':
                        print('Você jogou os dados')
                        print(dados)
                        print()
                        if dados >= 7:
                          print('O inimigo vem pra cima e você com um só golpe o finaliza!!')
                          print()
                          escreva('Você e seus companheiros comemoram e terminam de saquear aquele castelo.')
                          print()
                          escreva('Depois de 2 dias de descanso vocês voltaram para Kattegatt')
                          print()
                          print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                          escreva('Durante a viagem de volta, você e seus companheiros vikings discutiram sobre como o lord Garric estava exercendo o seu governo em kattegatt.')
                          escreva('Neste momento, você pensou e se eu desafiar o lord Garric para uma batalha......')
                          escreva('Chegando em kattegatt, você reencontra a sua família e vai pra casa')
                          print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
                          escreva('Mais uma vez o sol sai da sua toca...... e aquele pensamento não sai da sua cabeça.')
                          escreva('você fala com astrid, pedindo um conselho, ela diz: "Eu acho que isso mudaria a nossa vida e a vida dos nossos filhos, pense, se você ganhar dele kattegatt pode virar um novo reino, não era isso que você sempre quis."')
                          print('''
          [1] sim   
          [2] Não, estou com medo   
                  ''')
                          escolha_59 = input('Você diz ')
                          if escolha_59 == '1':
                            print('sim, você tem razão, vou desafia-lo a uma batalha')
                            escreva('Imediatamente você se reuniu com os seus companheiros vinkings e foi até o lord garric.')
                            escreva('Chegando lá lord Garric saiu para ver oque estava acontecendo.')
                            escreva('você em alto e bom som grita: "Eu vim te desafiar Garric para uma batalha até a morte pelo trono de kattegatt."')
                            escreva('Lord Garric diz: "haahaahaaahaa!!! e vira as costas."')
                            escreva('Você diz: "está com medo, hahahaha!!!"')
                            escreva('A população começa a gritar: "COVARDEEEE!!, NÃO ACREDITO QUE ESSE É O HOMEM QUE SE DIZ SER O NOSSO LORD!!!!"')
                            escreva('Devido a pressão da população de kattegatt, o lord garric vai para a luta!!')
                            escreva('Uma roda é formada (o lord Garric parece estar nervoso, mas não o subestime.) ')
                            escreva('você diz: será travada uma batalha aqui hoje, até a morte, porque nós somos vikings e quando não estamos satisfeitos nós matamos Hahahahahah!')
                            print('A batalha começa...')
                            print('''
                    
                    
          [O inimigo é de nivel 10]        
                    
                    
                    ''')
                            print('lord Garric ataca com sua espada, que é bem melhor que a sua...')
                            print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                            escolha_72 = input('Sua escolha: ')
                            print('Você jogou os dados!!')
                            print(dados)
                            print()
                            if dados >= 7:
                              print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                              print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                              escolha_1102 = input('Sua escolha: ')
                              if escolha_1102 == '1':
                                print('Você jogou os dados!!!')
                                print(dados)
                                if dados >= 7:
                                  print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                  escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                  texto = 'CONTINUA.......'
                                else:
                                  print(' os golpes de lord Garric o acerta e com um empurrão você o joga pra longe')
                              print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                              escolha_1022 = input('Sua escolha: ')
                              if escolha_1022 == '1':
                                print('Você jogou os dados!!!')
                                print(dados)
                                if dados >= 7:
                                  print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                  escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                  texto = 'CONTINUA.......'
                                else:
                                   print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                   escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                   texto = 'CONTINUA.......'
                                  
                            else:
                              print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                              print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                              escolha_102 = input('Sua escolha: ')
                              if escolha_102 == '1':
                                print('Você jogou os dados!!!')
                                print(dados)
                                if dados >= 7:
                                  print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                  escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                  texto = 'CONTINUA.......'
                                else:
                                   print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                   escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                   texto = 'CONTINUA.......'
                                  
                                    
                                  
                                  
                          else: 
                            print('Bom, se você é um medroso não deveria ser um viking...')
                            texto = 'CONTINUAÇÂO PARA MEDROSOS EM BREVE!!!'              
    
          elif escolha_3 == '2':
            print("Você entrou na cabana do vidente!!!")
            pergunta = input("Faça uma pergunta para o vidente: ")
            escreva('ele diz: "Eu vejo um corvo, e o corvo é você e esse corvo está com uma planta na boca. \nIsto é tudo que os Deuses me permitem falar."')
            print()
            escreva('Ele estende a mão e você a lambe (isto é um sinal de reverência)')
            print()
            escreva('Depois disso você vai conversar com o lord Gorric.')
            print()
            escreva('Você fica em pé demonstrando superioridade ele fica um pouco desconfortável e logo pergunta: "oque quer meu caro Ragnar?" \nVocê diz em um tom alto: "Quando vamos para a expedição?" \nele diz com um voz sarcástica: "nunca, e eu ja te falei o porque, agora vá" \nVocê ri dizendo: "Você vai se arrepender disso, você sabe que lá fora existem reinos, povos e tesouros escondidos esperando alguém achar, porém a sua visão limitada te impede de exergar tal riqueza " \nDepois disso você voltou pra casa e armou um plano com os guerreiros de kattegat, com a intenção de pegar os barcos escondido e viajar')
            print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
            escreva('você e mais três barcos foram em direção ao norte em busca de terra...')
            print()
            escreva('Depois de 3 dias vocês acharam um lugar.')
            print('''                              |>>>                              
                                  |                                 
                    |>>>      _  _|_  _         |>>>                
                    |        |;| |;| |;|        |                   
                _  _|_  _    \\.    .  /    _  _|_  _               
               |;|_|;|_|;|    \\:. ,  /    |;|_|;|_|;|              
               \\..      /    ||;   . |    \\.    .  /              
                \\.  ,  /     ||:  .  |     \\:  .  /               
                 ||:   |_   _ ||_ . _ | _   _||:   |                
                 ||:  .|||_|;|_|;|_|;|_|;|_|;||:.  |                
                 ||:   ||.    .     .      . ||:  .|                
                 ||: . || .     . .   .  ,   ||:   |       \,/      
                 ||:   ||:  ,  _______   .   ||: , |            /`\ 
                 ||:   || .   /+++++++\    . ||:   |                
                 ||:   ||.    |+++++++| .    ||: . |                
              __ ||: . ||: ,  |+++++++|.  . _||_   |                
     ____--`~    '--~~__|.    |+++++__|----~    ~`---,              
-~--~                   ~---__|,--~'                  ~~----_____-~''')
            escreva('Um castelo que a princípio tinha acabado de ser invadido por outros gurreiros, vocês entraram para vasculhar e ver se ainda tinha espólios perdidos, quando de repente surge um soldado e te ataca!!!')
            print('''
      [1] rolar os dados
          ''')
            escolha_3874 = input('Sua escolha: ')
            if escolha_3874 == '1':
              print('você jogou os dados!!')
              dados = random.randint(1,10)
              print(dados)
              if dados >= 7:
                print('você puxou a espada a tempo e consegui se defender!!')
                print()
                print('''
              
      [O inimigo é de nível 3]
              
              ''')
                print()
                print('Ele te ataca novamente!!!')
                print()
                print('''
      [1] rolar os dados
          ''')
                escolha_5871 = input('Sua escolha: ')
                if escolha_5871 == '1':
                      print('Você jogou os dados')
                      print(dados)
                      print()
                      if dados >= 7:
                            print('O inimigo vem pra cima e você com um só golpe o finaliza!!')
                            print()
                            escreva('Você e seus companheiros comemoram e terminam de saquear aquele castelo.')
                            print()
                            escreva('Depois de 2 dias de descanso vocês voltaram para Kattegatt')
                            print()
                            print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                            escreva('Durante a viagem de volta, você e seus companheiros vikings discutiram sobre como o lord Garric estava exercendo o seu governo em kattegatt.')
                            escreva('Neste momento, você pensou e se eu desafiar o lord Garric para uma batalha......')
                            escreva('Chegando em kattegatt, você reencontra a sua família e vai pra casa')
                            print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
                            escreva('Mais uma vez o sol sai da sua toca...... e aquele pensamento não sai da sua cabeça.')
                            escreva('você fala com astrid, pedindo um conselho, ela diz: "Eu acho que isso mudaria a nossa vida e a vida dos nossos filhos, pense, se você ganhar dele kattegatt pode virar um novo reino, não era isso que você sempre quis."')
                            print('''
          [1] sim   
          [2] Não, estou com medo   
                  ''')
                            escolha_5879 = input('Você diz ')
                            if escolha_5879 == '1':
                                  print('sim, você tem razão, vou desafia-lo a uma batalha')
                                  escreva('Imediatamente você se reuniu com os seus companheiros vinkings e foi até o lord garric.')
                                  escreva('Chegando lá lord Garric saiu para ver oque estava acontecendo.')
                                  escreva('você em alto e bom som grita: "Eu vim te desafiar Garric para uma batalha até a morte pelo trono de kattegatt."')
                                  escreva('Lord Garric diz: "haahaahaaahaa!!! e vira as costas."')
                                  escreva('Você diz: "está com medo, hahahaha!!!"')
                                  escreva('A população começa a gritar: "COVARDEEEE!!, NÃO ACREDITO QUE ESSE É O HOMEM QUE SE DIZ SER O NOSSO LORD!!!!"')
                                  escreva('Devido a pressão da população de kattegatt, o lord garric vai para a luta!!')
                                  escreva('Uma roda é formada (o lord Garric parece estar nervoso, mas não o subestime.) ')
                                  escreva('você diz: será travada uma batalha aqui hoje, até a morte, porque nós somos vikings e quando não estamos satisfeitos nós matamos Hahahahahah!')
                                  print('A batalha começa...')
                                  print('''
                    
                    
          [O inimigo é de nivel 10]        
                    
                    
                    ''')
                                  print('lord Garric ataca com sua espada, que é bem melhor que a sua...')
                                  print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                  escolha_7872 = input('Sua escolha: ')
                                  print('Você jogou os dados!!')
                                  print(dados)
                                  print()
                                  if dados >= 7:
                                        print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                                        print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                        escolha_18702 = input('Sua escolha: ')
                                        if escolha_18702 == '1':
                                          print('Você jogou os dados!!!')
                                          print(dados)
                                          if dados >= 7:
                                              print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                              escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                              texto = 'CONTINUA.......'
                                          else:
                                            print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                            escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                            texto = 'CONTINUA.......'
                                  else:
                                     print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                     escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                     texto = 'CONTINUA.......'        
                                          
                                          
                                        
                            else: 
                                  print('Bom, se você é um medroso não deveria ser um viking...')
                                  texto = 'CONTINUAÇÂO PARA MEDROSOS EM BREVE!!!'              
    
 
    elif escolha_2 == '2':
          print('Enquanto olhava para as estrelas você lembrava da histórias que seu pai contava......')
          escreva('Um novo dia começa o sol está brilhando!!!! \nVocê passa pela cidade de manhã e encontra o seu amigo seagurd, \ne o chama para ir conversar com o lord Garric (o lord Garric é o lord de kattegat, um líder incompetente e sem visão). \nNo caminho você passa na frente da cabana de um vidente....')
          print('''
      [1] ir conversar com o lord Garric
      [2] entrar na cabana do vidente
                ''')
          escolha_66 = input("Sua escolha: ")
          if escolha_66 == '1':
                print('Você chegou na casa do lord Garric, ele te convida para sentar-se')
                print('''
      [1] Sentar
      [2] ficar em pé
                      ''')
                escolha_44 = input('Sua escolha: ')
                if escolha_44 == '1':
                      print('Você se sentou olhando para o lord Garric, ele fica um pouco desconfortável e logo pergunta: "oque quer meu caro Ragnar?" \nVocê diz em um tom alto: "Quando vamos para a expedição?" \nele diz com um voz sarcástica: "nunca, e eu ja te falei o porque, agora vá" \nVocê ri dizendo: "Você vai se arrepender disso, você sabe que lá fora existem reinos, povos e tesouros escondidos esperando alguém achar, porém a sua visão limitada te impede de exergar tal riqueza " \nDepois disso você voltou pra casa e armou um plano com os guerreiros de kattegat, com a intenção de pegar os barcos escondido e viajar')
                      print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                      
                      escreva('você e mais três barcos foram em direção ao norte em busca de terra...')
                      print()
                      escreva('Depois de 3 dias vocês acharam um lugar.')
                      print('''                              |>>>                              
                                  |                                 
                    |>>>      _  _|_  _         |>>>                
                    |        |;| |;| |;|        |                   
                _  _|_  _    \\.    .  /    _  _|_  _               
               |;|_|;|_|;|    \\:. ,  /    |;|_|;|_|;|              
               \\..      /    ||;   . |    \\.    .  /              
                \\.  ,  /     ||:  .  |     \\:  .  /               
                 ||:   |_   _ ||_ . _ | _   _||:   |                
                 ||:  .|||_|;|_|;|_|;|_|;|_|;||:.  |                
                 ||:   ||.    .     .      . ||:  .|                
                 ||: . || .     . .   .  ,   ||:   |       \,/      
                 ||:   ||:  ,  _______   .   ||: , |            /`\ 
                 ||:   || .   /+++++++\    . ||:   |                
                 ||:   ||.    |+++++++| .    ||: . |                
              __ ||: . ||: ,  |+++++++|.  . _||_   |                
     ____--`~    '--~~__|.    |+++++__|----~    ~`---,              
-~--~                   ~---__|,--~'                  ~~----_____-~''')
                      escreva('Um castelo que a princípio tinha acabado de ser invadido por outros gurreiros, vocês entraram para vasculhar e ver se ainda tinha espólios perdidos, quando de repente surge um soldado e te ataca!!!')
                      print('''
      [1] rolar os dados
          ''')
                      escolha_364 = input('Sua escolha: ')
                      if escolha_364 == '1':
                        print('você jogou os dados!!')
                        dados = random.randint(1,10)
                        print(dados)
                        if dados >= 7:
                          print('você puxou a espada a tempo e consegui se defender!!')
                          print()
                          print('''
              
      [O inimigo é de nível 3]
              
              ''')
                          print()
                          print('Ele te ataca novamente!!!')
                          print()
                          print('''
      [1] rolar os dados
          ''')
                          escolha_571 = input('Sua escolha: ')
                          if escolha_571 == '1':
                            print('Você jogou os dados')
                            print(dados)
                            print()
                            if dados >= 7:
                              print('O inimigo vem pra cima e você com um só golpe o finaliza!!')
                              print()
                              escreva('Você e seus companheiros comemoram e terminam de saquear aquele castelo.')
                              print()
                              escreva('Depois de 2 dias de descanso vocês voltaram para Kattegatt')
                              print()
                              print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                              escreva('Durante a viagem de volta, você e seus companheiros vikings discutiram sobre como o lord Garric estava exercendo o seu governo em kattegatt.')
                              escreva('Neste momento, você pensou e se eu desafiar o lord Garric para uma batalha......')
                              escreva('Chegando em kattegatt, você reencontra a sua família e vai pra casa')
                              print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
                              escreva('Mais uma vez o sol sai da sua toca...... e aquele pensamento não sai da sua cabeça.')
                              escreva('você fala com astrid, pedindo um conselho, ela diz: "Eu acho que isso mudaria a nossa vida e a vida dos nossos filhos, pense, se você ganhar dele kattegatt pode virar um novo reino, não era isso que você sempre quis."')
                              print('''
          [1] sim   
          [2] Não, estou com medo   
                  ''')
                              escolha_599 = input('Você diz ')
                              if escolha_599 == '1':
                                  print('sim, você tem razão, vou desafia-lo a uma batalha')
                                  escreva('Imediatamente você se reuniu com os seus companheiros vinkings e foi até o lord garric.')
                                  escreva('Chegando lá lord Garric saiu para ver oque estava acontecendo.')
                                  escreva('você em alto e bom som grita: "Eu vim te desafiar Garric para uma batalha até a morte pelo trono de kattegatt."')
                                  escreva('Lord Garric diz: "haahaahaaahaa!!! e vira as costas."')
                                  escreva('Você diz: "está com medo, hahahaha!!!"')
                                  escreva('A população começa a gritar: "COVARDEEEE!!, NÃO ACREDITO QUE ESSE É O HOMEM QUE SE DIZ SER O NOSSO LORD!!!!"')
                                  escreva('Devido a pressão da população de kattegatt, o lord garric vai para a luta!!')
                                  escreva('Uma roda é formada (o lord Garric parece estar nervoso, mas não o subestime.) ')
                                  escreva('você diz: será travada uma batalha aqui hoje, até a morte, porque nós somos vikings e quando não estamos satisfeitos nós matamos Hahahahahah!')
                                  print('A batalha começa...')
                                  print('''
                    
                    
          [O inimigo é de nivel 10]        
                    
                    
                    ''')
                                  print('lord Garric ataca com sua espada, que é bem melhor que a sua...')
                                  print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                  escolha_7228 = input('Sua escolha: ')
                                  print('Você jogou os dados!!')
                                  print(dados)
                                  print()
                                  if dados >= 7:
                                        print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                                        print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                        escolha_13028 = input('Sua escolha: ')
                                        if escolha_13028 == '1':
                                          print('Você jogou os dados!!!')
                                          print(dados)
                                          if dados >= 7:
                                            print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                            escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                            texto = 'CONTINUA.......'
                                          else:
                                             print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                             escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                             texto = 'CONTINUA.......'
                                  else:
                                     print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                                     print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                     escolha_1028 = input('Sua escolha: ')
                                     if escolha_1028 == '1':
                                       print('Você jogou os dados!!!')
                                       print(dados)
                                       if dados >= 7:
                                        print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                        escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                        texto = 'CONTINUA.......'
                                       else:
                                          print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                          escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                          texto = 'CONTINUA.......'
                                    
                                        
                                      
                              else: 
                                  print('Bom, se você é um medroso não deveria ser um viking...')
                                  texto = 'CONTINUAÇÂO PARA MEDROSOS EM BREVE!!!'
                                  
                                        
    
                elif escolha_44 == '2':
                      print('Você fica em pé demonstrando superioridade ele fica um pouco desconfortável e logo pergunta: "oque quer meu caro Ragnar?" \nVocê diz em um tom alto: "Quando vamos para a expedição?" \nele diz com um voz sarcástica: "nunca, e eu ja te falei o porque, agora vá" \nVocê ri dizendo: "Você vai se arrepender disso, você sabe que lá fora existem reinos, povos e tesouros escondidos esperando alguém achar, porém a sua visão limitada te impede de exergar tal riqueza " \nDepois disso você voltou pra casa e armou um plano com os guerreiros de kattegat, com a intenção de pegar os barcos escondido e viajar')
                      print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
    escreva('você e mais três barcos foram em direção ao norte em busca de terra...')
    print()
    escreva('Depois de 3 dias vocês acharam um lugar.')
    print('''                              |>>>                              
                                  |                                 
                    |>>>      _  _|_  _         |>>>                
                    |        |;| |;| |;|        |                   
                _  _|_  _    \\.    .  /    _  _|_  _               
               |;|_|;|_|;|    \\:. ,  /    |;|_|;|_|;|              
               \\..      /    ||;   . |    \\.    .  /              
                \\.  ,  /     ||:  .  |     \\:  .  /               
                 ||:   |_   _ ||_ . _ | _   _||:   |                
                 ||:  .|||_|;|_|;|_|;|_|;|_|;||:.  |                
                 ||:   ||.    .     .      . ||:  .|                
                 ||: . || .     . .   .  ,   ||:   |       \,/      
                 ||:   ||:  ,  _______   .   ||: , |            /`\ 
                 ||:   || .   /+++++++\    . ||:   |                
                 ||:   ||.    |+++++++| .    ||: . |                
              __ ||: . ||: ,  |+++++++|.  . _||_   |                
     ____--`~    '--~~__|.    |+++++__|----~    ~`---,              
-~--~                   ~---__|,--~'                  ~~----_____-~''')
    escreva('Um castelo que a princípio tinha acabado de ser invadido por outros gurreiros, vocês entraram para vasculhar e ver se ainda tinha espólios perdidos, quando de repente surge um soldado e te ataca!!!')
    print('''
      [1] rolar os dados
          ''')
    escolha_3664 = input('Sua escolha: ')
    if escolha_3664 == '1':
          print('você jogou os dados!!')
          dados = random.randint(1,10)
          print(dados)
          if dados >= 7:
                print('você puxou a espada a tempo e consegui se defender!!')
                print()
                print('''
              
      [O inimigo é de nível 3]
              
              ''')
                print()
                print('Ele te ataca novamente!!!')
                print()
                print('''
      [1] rolar os dados
          ''')
                escolha_511 = input('Sua escolha: ')
                if escolha_511 == '1':
                      print('Você jogou os dados')
                      print(dados)
                      print()
                      if dados >= 7:
                            print('O inimigo vem pra cima e você com um só golpe o finaliza!!')
                            print()
                            escreva('Você e seus companheiros comemoram e terminam de saquear aquele castelo.')
                            print()
                            escreva('Depois de 2 dias de descanso vocês voltaram para Kattegatt')
                            print()
                            print('''                                                  
                                                
                                                  
                    :::: | ::                      
                  :::::: | ::                      
                 ::::::: | ::                      
                :::::::: | ::                      
              :::::::::: | :::                    
             ::::::::::: | ::::::                  
            :::::::::::: | ::::::::               
           ::::::::::::: | ::::::::::              
          :::::::::::::: | ::::::::::::            
          :::::::::::::: | ::::::::::::::          
          :::::::::::::: | ::::::::::::::::        
                          ::                      
          ::::::::::::::::::::::::::::::::::      
            ::::::::::::::::::::::::::::::        
              ::::::::::::::::::::::::::                   
              _____
     ______--`~    '--~~____           ----~ _____ ~`---,              
__  -~--~                   ~---__|,--~'                  ~~----_____-~            
                                                  
                                                  ''')
                            escreva('Durante a viagem de volta, você e seus companheiros vikings discutiram sobre como o lord Garric estava exercendo o seu governo em kattegatt.')
                            escreva('Neste momento, você pensou e se eu desafiar o lord Garric para uma batalha......')
                            escreva('Chegando em kattegatt, você reencontra a sua família e vai pra casa')
                            print('''             ####                    
                          ####                    
                          ####                    
          ####            ####            ##      
          ####                          ######    
            ####      ############    ######      
                  ##################    ##        
                ######################            
                ########################          
              ##########################          
              ############################        
    ######    ############################  ######
    ######    ############################  ######
              ############################        
              ############################        
              ##########################          
                ######################            
                  ##################              
            ####    ##############    ####        
          ######                        ####      
          ####                            ##      
                          ####                    
                          ####                    
                          ####                    
                                                  ''')
                            escreva('Mais uma vez o sol sai da sua toca...... e aquele pensamento não sai da sua cabeça.')
                            escreva('você fala com astrid, pedindo um conselho, ela diz: "Eu acho que isso mudaria a nossa vida e a vida dos nossos filhos, pense, se você ganhar dele kattegatt pode virar um novo reino, não era isso que você sempre quis."')
                            print('''
          [1] sim   
          [2] Não, estou com medo   
                  ''')
                            escolha_529 = input('Você diz ')
                            if escolha_529 == '1':
                                  print('sim, você tem razão, vou desafia-lo a uma batalha')
                                  escreva('Imediatamente você se reuniu com os seus companheiros vinkings e foi até o lord garric.')
                                  escreva('Chegando lá lord Garric saiu para ver oque estava acontecendo.')
                                  escreva('você em alto e bom som grita: "Eu vim te desafiar Garric para uma batalha até a morte pelo trono de kattegatt."')
                                  escreva('Lord Garric diz: "haahaahaaahaa!!! e vira as costas."')
                                  escreva('Você diz: "está com medo, hahahaha!!!"')
                                  escreva('A população começa a gritar: "COVARDEEEE!!, NÃO ACREDITO QUE ESSE É O HOMEM QUE SE DIZ SER O NOSSO LORD!!!!"')
                                  escreva('Devido a pressão da população de kattegatt, o lord garric vai para a luta!!')
                                  escreva('Uma roda é formada (o lord Garric parece estar nervoso, mas não o subestime.) ')
                                  escreva('você diz: será travada uma batalha aqui hoje, até a morte, porque nós somos vikings e quando não estamos satisfeitos nós matamos Hahahahahah!')
                                  print('A batalha começa...')
                                  print('''
                    
                    
          [O inimigo é de nivel 10]        
                    
                    
                    ''')
                                  print('lord Garric ataca com sua espada, que é bem melhor que a sua...')
                                  print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                  escolha_732 = input('Sua escolha: ')
                                  print('Você jogou os dados!!')
                                  print(dados)
                                  print()
                                  if dados >= 7:
                                        print('Você defende os golpes de lord Garric e com um empurrão você o joga pra longe')
                                        print('''
                  
          [1] Role os dados!!     
                  
                  ''')
                                  escolha_1302 = input('Sua escolha: ')
                                  if escolha_1302 == '1':
                                        print('Você jogou os dados!!!')
                                  print(dados)
                                  if dados >= 7:
                                        print('Lord Garric vem denovo correndo, você desvia e abaixando a espada você acerta ele, um golpe fatal')
                                        escreva('Parabéns, você se tornou o novo Lord de Kattegatt')
                                        texto = 'CONTINUA.......'
                            else: 
                                  print('Bom, se você é um medroso não deveria ser um viking...')
                                  texto = 'CONTINUAÇÂO PARA MEDROSOS EM BREVE!!!'           
    
          
else:
    print('Errado Digite novamente!!!')
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[12], line 14
#      11 import time
#      13 pygame.init
# ---> 14 pygame.mixer.music.load('a horror-sinister-power-rising-epic-dark- soundtracknocopyrightmusic98837.mp3')
#      15 pygame.mixer.music.play()
#      17 while pygame.mixer.music.get_busy():
#
# error: mixer not initialized
